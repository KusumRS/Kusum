# %% [markdown]
# Data Pre-Processing

# %%
# !pip install feature_engine

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 music=pd.read_csv('C:/Users/Adithya Arunganesh/Desktop/Projects/Data  Viz Challenge/Spotify/spotify_songs.csv')

# %%
music.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32832 entries, 0 to 32831
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_name                32827 non-null  object
#  1   track_artist              32827 non-null  object
#  2   track_popularity          32832 non-null  int64
#  3   track_album_name          32827 non-null  object
#  4   track_album_release_date  32832 non-null  object
#  5   playlist_name             32832 non-null  object
#  6   playlist_genre            32832 non-null  object
#  7   playlist_subgenre         32832 non-null  object
#  8   danceability              32832 non-null  float64
#  9   energy                    32832 non-null  float64
#  10  key                       32832 non-null  int64
#  11  loudness                  32832 non-null  float64
#  12  mode                      32832 non-null  int64
# ...

# %%
music.head()
# Out:
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
#
#    track_popularity                                   track_album_name  \
# 0                66  I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                67                    Memories (Dillon Francis Remix)
# 2                70                    All the Time (Don Diablo Remix)
# 3                60                        Call You Mine - The Remixes
# 4                69            Someone You Loved (Future Humans Remix)
#
#   track_album_release_date playlist_name playlist_genre playlist_subgenre  \
# ...

# %%
music.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32832.000000  32832.000000  32832.000000  32832.000000
# mean          42.476243      0.654845      0.698621      5.374330
# std           24.983993      0.145085      0.180912      3.611622
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32832.000000  32832.000000  32832.000000  32832.000000
# mean      -6.719516      0.565729      0.107069      0.175337
# std        2.988480      0.495668      0.101315      0.219635
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %% [markdown]
# Missing values

# %%
music.isnull().sum()
# Out:
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
music=music.dropna()

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32827 entries, 0 to 32831
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_name                32827 non-null  object
#  1   track_artist              32827 non-null  object
#  2   track_popularity          32827 non-null  int64
#  3   track_album_name          32827 non-null  object
#  4   track_album_release_date  32827 non-null  object
#  5   playlist_name             32827 non-null  object
#  6   playlist_genre            32827 non-null  object
#  7   playlist_subgenre         32827 non-null  object
#  8   danceability              32827 non-null  float64
#  9   energy                    32827 non-null  float64
#  10  key                       32827 non-null  int64
#  11  loudness                  32827 non-null  float64
#  12  mode                      32827 non-null  int64
# ...

# %%
music_artists=list(music['track_artist'].unique())

# %%
print(len(music_artists))
#we have 10,692 unique artists
# Out:
# 10692

# %%
music_genre=list(music['playlist_genre'].unique())
music_genre
# Out:
# ['pop', 'rap', 'rock', 'latin', 'r&b', 'edm']

# %%
print(len(music_genre))
# Out:
# 6

# %%
music_subgenre=list(music['playlist_subgenre'].unique())
music_subgenre
# Out:
# ['dance pop',
#  'post-teen pop',
#  'electropop',
#  'indie poptimism',
#  'hip hop',
#  'southern hip hop',
#  'gangster rap',
#  'trap',
#  'album rock',
#  'classic rock',
#  'permanent wave',
#  'hard rock',
#  'tropical',
#  'latin pop',
#  'reggaeton',
#  'latin hip hop',
#  'urban contemporary',
#  'hip pop',
#  'new jack swing',
#  'neo soul',
#  'electro house',
#  'big room',
#  'pop edm',
#  'progressive electro house']

# %%
print(len(music_subgenre))
# Out:
# 24

# %%
music_corr=music.corr()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,9))
music_hm = sns.heatmap(music_corr,cmap='magma_r',annot=True,ax=ax)

# %%
#The popluarity of a song correlated with
# Out:
#   File "<ipython-input-19-b3bf3d60b5a2>", line 1
#     The popluarity of a song correlated with
#                  ^
# SyntaxError: invalid syntax

# %%
genre_plot = sns.countplot(music['playlist_genre'],palette='inferno')

# %%
subgenre_plot = sns.countplot(music['playlist_subgenre'],palette='inferno')
subgenre_plot.set_xticklabels(subgenre_plot.get_xticklabels(),rotation=90,size=15)
subgenre_plot.patches[-1].set_fc('b')

# %%
#Top artists

# %%
top_10_artist = music['track_artist'].value_counts()[:10]
top_10_genres = music['playlist_genre'].value_counts()[:10]
top_10_songs = music.iloc[music['track_popularity'].nlargest(10).index,:]
top_10_artist.to_frame()
top_10_songs
# Out:
#                                   track_name  track_artist  track_popularity  \
# 1551                            Dance Monkey   Tones and I               100
# 20095  Own It (feat. Ed Sheeran & Burna Boy)       Stormzy                88
# 20096                    Futsal Shuffle 2020  Lil Uzi Vert                91
# 21472                     Times (feat. Robn)      Moh Flow                32
# 23108                                Circles   Post Malone                98
# 30206                               Memories      Maroon 5                98
# 687                                     Tusa       KAROL G                98
# 711                                 Memories      Maroon 5                98
# 716                          Blinding Lights    The Weeknd                98
# 1300                                Memories      Maroon 5                98
#
#                                   track_album_name track_album_release_date  \
# ...
